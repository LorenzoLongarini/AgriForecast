# %%
import pandas as pd

def load_and_prepare_data(file_path):
    
    data = pd.read_excel(file_path)
    
    data.fillna(method='ffill', inplace=True)
    data = data.drop(columns=['day'])

    data = data.replace(',', '.', regex=True).astype(float)

    
    # data_normalized = (data - data.mean()) / data.std()
    
    return data


df = load_and_prepare_data('../assets/MisureAgugliano.xlsx')
df
# Out:
# C:\Users\lollo\AppData\Local\Temp\ipykernel_55468\3492835222.py:7: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data.fillna(method='ffill', inplace=True)
#      tair_mean  tair_max  tair_min  huair_mean  huair_max  huair_min  \
# 0          8.4      15.4       0.3        75.8       95.0       52.0
# 1         12.9      18.2       9.1        66.6       79.4       51.4
# 2         13.0      18.4       3.6        60.8       85.7       42.4
# 3          3.8       5.4      -0.4        80.5       90.4       69.2
# 4          4.0      10.2      -2.1        75.8       91.1       55.2
# ..         ...       ...       ...         ...        ...        ...
# 137       13.8      19.7       6.4        77.3       95.0       55.6
# 138       16.0      19.7      11.8        82.6       94.5       56.5
# 139       14.3      19.1       8.5        87.4       96.1       76.3
# 140       19.4      25.6      13.4        83.2       97.0       57.4
# 141       18.4      18.8      17.6        93.4       95.1       90.6
#
#      pressure_mean  pressure_max  pressure_min  pdew_mean  ...  etp_tot  \
# 0           1011.5        1013.3        1008.7        3.9  ...      1.1
# 1           1005.6        1008.7        1003.7        6.7  ...      1.0
# 2           1005.6        1008.4        1002.4        5.2  ...      2.3
# 3           1019.6        1022.2        1017.8        0.7  ...      0.4
# 4           1018.6        1020.7        1017.6       -0.1  ...      0.9
# ..             ...           ...           ...        ...  ...      ...
# 137         1011.4        1012.7        1009.0        9.5  ...      3.3
# 138         1009.4        1010.6        1008.3       12.8  ...      1.6
# 139         1012.2        1013.6        1010.5       12.2  ...      2.8
# 140         1006.4        1007.9        1003.3       16.2  ...      3.0
# 141         1001.8        1003.8        1000.6       17.3  ...      0.1
#
#      etp_xKc  sol_rad_mean  sol_rad_tot  sol_rad_hour  sol_rad_max  \
# 0        0.2        69.278     1662.675           5.0      392.401
# 1        0.1        42.864     1028.728           3.0      407.593
# 2        0.4        85.907     2061.777           6.0      381.121
# 3        0.1        36.374      872.973           2.0      435.447
# 4        0.1        67.664     1623.925           5.0      366.849
# ..       ...           ...          ...           ...          ...
# 137      0.5       241.005     5784.127          11.0     1077.760
# 138      0.2       109.867     2636.796           8.0      688.811
# 139      0.4       213.128     5115.061          11.0     1062.720
# 140      0.4       189.771     4554.498          10.0      849.639
# 141      0.0        28.581      285.815           1.0      167.119
#
#      sol_rad_min  wind_mean  wind_max  wind_min
# 0         10.359        0.9       4.8      15.9
# 1         10.052        1.0       5.2      15.2
# 2         10.128        2.7       6.6       7.5
# 3         10.205        0.9       2.9       9.7
# 4         10.282        0.9       3.0      17.9
# ..           ...        ...       ...       ...
# 137       10.052        0.9       3.2       1.3
# 138       10.052        0.2       1.3       1.3
# 139       10.128        0.8       3.0       1.1
# 140       10.282        0.6       2.4       1.7
# 141       10.512        0.5       3.4       1.7
#
# [142 rows x 23 columns]
